# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0,20,40,80% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in southern hemispheres there is a flurry of cities with over 30 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests , json
import time

# Import API key
import openweathermapy.core as owm
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        


# Print the city count to confirm sufficient count
citylen = len(cities)
print(citylen)
# Out:
# 630

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create settings dictionary with information we're interested in
settings = {"units": "metric", "appid": api_key}
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

i = 0
weather_data_list = []
print ("Beginning Data Retrieval")
print ("-------------------------------------------------------------------------")
for city in cities:
    i = i + 1
    response = requests.get(query_url + city).json()
    #response = owm.get_current(city, **settings)
    #weather_data_city_json = response.json()
    if response["cod"] != "404":
        weather_data_list.append(response)
        print(f"Processing Record {i} of Set {citylen} | {city}")

    else: 
        print("City not found. Skipping...") 
    time.sleep(1)

print ("-------------------------------------------------------------------------")
print ("Data Retrieval Complete")
print ("-------------------------------------------------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------------------------------------------------
# Processing Record 1 of Set 630 | rio cuarto
# Processing Record 2 of Set 630 | caracuaro
# Processing Record 3 of Set 630 | kudymkar
# Processing Record 4 of Set 630 | polovinnoye
# Processing Record 5 of Set 630 | coihaique
# Processing Record 6 of Set 630 | ushuaia
# Processing Record 7 of Set 630 | clyde river
# Processing Record 8 of Set 630 | jamestown
# City not found. Skipping...
# Processing Record 10 of Set 630 | punta arenas
# Processing Record 11 of Set 630 | tuktoyaktuk
# Processing Record 12 of Set 630 | hay river
# Processing Record 13 of Set 630 | pathalgaon
# City not found. Skipping...
# Processing Record 15 of Set 630 | bud
# Processing Record 16 of Set 630 | miri
# City not found. Skipping...
# Processing Record 18 of Set 630 | hobart
# Processing Record 19 of Set 630 | vaini
# Processing Record 20 of Set 630 | rio gallegos
# Processing Record 21 of Set 630 | dandong
# Processing Record 22 of Set 630 | rikitea
# Processing Record 23 of Set 630 | khatanga
# Processing Record 24 of Set 630 | komsomolskiy
# Processing Record 25 of Set 630 | tuatapere
# Processing Record 26 of Set 630 | namatanai
# City not found. Skipping...
# Processing Record 28 of Set 630 | gryazovets
# Processing Record 29 of Set 630 | angoche
# Processing Record 30 of Set 630 | buta
# Processing Record 31 of Set 630 | nikolskoye
# Processing Record 32 of Set 630 | tasiilaq
# Processing Record 33 of Set 630 | cape town
# Processing Record 34 of Set 630 | busselton
# Processing Record 35 of Set 630 | souillac
# Processing Record 36 of Set 630 | alekseyevsk
# Processing Record 37 of Set 630 | ylivieska
# Processing Record 38 of Set 630 | santiago del estero
# Processing Record 39 of Set 630 | castro
# Processing Record 40 of Set 630 | mataura
# Processing Record 41 of Set 630 | ginda
# Processing Record 42 of Set 630 | paamiut
# City not found. Skipping...
# Processing Record 44 of Set 630 | quatre cocos
# Processing Record 45 of Set 630 | albany
# Processing Record 46 of Set 630 | limoges
# Processing Record 47 of Set 630 | kapaa
# Processing Record 48 of Set 630 | saint-philippe
# Processing Record 49 of Set 630 | narsaq
# Processing Record 50 of Set 630 | sanghar
# Processing Record 51 of Set 630 | rantepao
# Processing Record 52 of Set 630 | carnarvon
# City not found. Skipping...
# Processing Record 54 of Set 630 | kloulklubed
# Processing Record 55 of Set 630 | puerto ayacucho
# Processing Record 56 of Set 630 | brookhaven
# Processing Record 57 of Set 630 | alamosa
# Processing Record 58 of Set 630 | esperance
# Processing Record 59 of Set 630 | kroya
# Processing Record 60 of Set 630 | arraial do cabo
# Processing Record 61 of Set 630 | dikson
# Processing Record 62 of Set 630 | hilo
# Processing Record 63 of Set 630 | new norfolk
# Processing Record 64 of Set 630 | salalah
# Processing Record 65 of Set 630 | kavaratti
# Processing Record 66 of Set 630 | sallins
# Processing Record 67 of Set 630 | eyl
# Processing Record 68 of Set 630 | bethel
# City not found. Skipping...
# Processing Record 70 of Set 630 | burnie
# Processing Record 71 of Set 630 | ponta do sol
# Processing Record 72 of Set 630 | mahebourg
# Processing Record 73 of Set 630 | strezhevoy
# Processing Record 74 of Set 630 | lashio
# Processing Record 75 of Set 630 | rexburg
# Processing Record 76 of Set 630 | talgar
# Processing Record 77 of Set 630 | mocuba
# Processing Record 78 of Set 630 | porto walter
# Processing Record 79 of Set 630 | khoy
# Processing Record 80 of Set 630 | ust-ordynskiy
# Processing Record 81 of Set 630 | villefranche-de-rouergue
# Processing Record 82 of Set 630 | saldanha
# Processing Record 83 of Set 630 | barrow
# Processing Record 84 of Set 630 | hermanus
# Processing Record 85 of Set 630 | makow mazowiecki
# Processing Record 86 of Set 630 | severo-kurilsk
# Processing Record 87 of Set 630 | qaanaaq
# Processing Record 88 of Set 630 | san cristobal
# City not found. Skipping...
# Processing Record 90 of Set 630 | caraballeda
# Processing Record 91 of Set 630 | vila franca do campo
# Processing Record 92 of Set 630 | isiro
# Processing Record 93 of Set 630 | hille
# Processing Record 94 of Set 630 | bethanien
# City not found. Skipping...
# Processing Record 96 of Set 630 | flinders
# Processing Record 97 of Set 630 | tura
# Processing Record 98 of Set 630 | ilulissat
# Processing Record 99 of Set 630 | bara
# Processing Record 100 of Set 630 | kaitangata
# Processing Record 101 of Set 630 | guerrero negro
# Processing Record 102 of Set 630 | burns lake
# City not found. Skipping...
# Processing Record 104 of Set 630 | artigas
# Processing Record 105 of Set 630 | pleshanovo
# Processing Record 106 of Set 630 | xichang
# Processing Record 107 of Set 630 | hami
# Processing Record 108 of Set 630 | tupelo
# Processing Record 109 of Set 630 | helmsdale
# Processing Record 110 of Set 630 | itarema
# Processing Record 111 of Set 630 | nuuk
# Processing Record 112 of Set 630 | port alfred
# Processing Record 113 of Set 630 | cherskiy
# Processing Record 114 of Set 630 | ciudad real
# Processing Record 115 of Set 630 | port lincoln
# Processing Record 116 of Set 630 | ponta pora
# Processing Record 117 of Set 630 | atuona
# City not found. Skipping...
# Processing Record 119 of Set 630 | george
# Processing Record 120 of Set 630 | hendaye
# Processing Record 121 of Set 630 | tadepallegudem
# Processing Record 122 of Set 630 | korcula
# Processing Record 123 of Set 630 | tilichiki
# Processing Record 124 of Set 630 | pandan
# Processing Record 125 of Set 630 | kruisfontein
# Processing Record 126 of Set 630 | fortuna
# Processing Record 127 of Set 630 | mugur-aksy
# Processing Record 128 of Set 630 | maceio
# Processing Record 129 of Set 630 | abong mbang
# Processing Record 130 of Set 630 | bredasdorp
# Processing Record 131 of Set 630 | sola
# Processing Record 209 of Set 630 | cabo san lucas
# Processing Record 210 of Set 630 | ribeira grande
# City not found. Skipping...
# Processing Record 212 of Set 630 | meulaboh
# Processing Record 213 of Set 630 | marsh harbour
# Processing Record 214 of Set 630 | ambon
# Processing Record 215 of Set 630 | moshenskoye
# Processing Record 216 of Set 630 | emerald
# Processing Record 217 of Set 630 | lata
# Processing Record 218 of Set 630 | faanui
# City not found. Skipping...
# Processing Record 220 of Set 630 | bluff
# Processing Record 221 of Set 630 | los llanos de aridane
# Processing Record 222 of Set 630 | klaksvik
# Processing Record 223 of Set 630 | bubaque
# Processing Record 224 of Set 630 | victoria
# Processing Record 225 of Set 630 | harper
# Processing Record 226 of Set 630 | lebu
# Processing Record 227 of Set 630 | evensk
# Processing Record 228 of Set 630 | ramhormoz
# Processing Record 229 of Set 630 | antalaha
# Processing Record 230 of Set 630 | tambo
# Processing Record 231 of Set 630 | nemuro
# City not found. Skipping...
# Processing Record 233 of Set 630 | vredendal
# Processing Record 234 of Set 630 | kibondo
# Processing Record 235 of Set 630 | sao filipe
# City not found. Skipping...
# Processing Record 237 of Set 630 | amberley
# Processing Record 238 of Set 630 | port hardy
# Processing Record 239 of Set 630 | igarka
# Processing Record 240 of Set 630 | karratha
# Processing Record 241 of Set 630 | carutapera
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 244 of Set 630 | maturin
# Processing Record 245 of Set 630 | never
# Processing Record 246 of Set 630 | porto de moz
# Processing Record 247 of Set 630 | namibe
# Processing Record 248 of Set 630 | la rioja
# Processing Record 249 of Set 630 | yulara
# Processing Record 250 of Set 630 | na wa
# Processing Record 251 of Set 630 | vuktyl
# Processing Record 252 of Set 630 | talara
# Processing Record 253 of Set 630 | talnakh
# City not found. Skipping...
# Processing Record 255 of Set 630 | tarata
# Processing Record 256 of Set 630 | siena
# Processing Record 257 of Set 630 | lebedyn
# Processing Record 258 of Set 630 | kortkeros
# Processing Record 259 of Set 630 | kirkwall
# Processing Record 260 of Set 630 | nanortalik
# Processing Record 261 of Set 630 | wote
# Processing Record 262 of Set 630 | payette
# Processing Record 263 of Set 630 | les escoumins
# Processing Record 264 of Set 630 | saint-pierre
# Processing Record 265 of Set 630 | aklavik
# Processing Record 266 of Set 630 | provideniya
# Processing Record 267 of Set 630 | kailua
# Processing Record 268 of Set 630 | onda
# Processing Record 269 of Set 630 | verkhovazhye
# Processing Record 270 of Set 630 | hasaki
# Processing Record 271 of Set 630 | mercedes
# Processing Record 272 of Set 630 | olkhovka
# Processing Record 273 of Set 630 | east london
# Processing Record 274 of Set 630 | kampong cham
# Processing Record 275 of Set 630 | gravdal
# Processing Record 276 of Set 630 | warrnambool
# Processing Record 277 of Set 630 | kitakata
# Processing Record 278 of Set 630 | jacqueville
# Processing Record 279 of Set 630 | valkeakoski
# City not found. Skipping...
# City not found. Skipping...
# Processing Record
# Processing Record 375 of Set 630 | georgetown
# Processing Record 376 of Set 630 | pirgos
# Processing Record 377 of Set 630 | norman wells
# Processing Record 378 of Set 630 | griffith
# Processing Record 379 of Set 630 | auki
# Processing Record 380 of Set 630 | codrington
# City not found. Skipping...
# Processing Record 382 of Set 630 | chippewa falls
# Processing Record 383 of Set 630 | saint stephen
# Processing Record 384 of Set 630 | helong
# Processing Record 385 of Set 630 | cayenne
# Processing Record 386 of Set 630 | lakes entrance
# Processing Record 387 of Set 630 | poum
# Processing Record 388 of Set 630 | nouakchott
# Processing Record 389 of Set 630 | inhambane
# Processing Record 390 of Set 630 | ajdabiya
# Processing Record 391 of Set 630 | shingu
# City not found. Skipping...
# Processing Record 393 of Set 630 | tevriz
# Processing Record 394 of Set 630 | chhapar
# Processing Record 395 of Set 630 | asosa
# Processing Record 396 of Set 630 | elizabeth city
# Processing Record 397 of Set 630 | tandil
# Processing Record 398 of Set 630 | waingapu
# Processing Record 399 of Set 630 | nioro
# Processing Record 400 of Set 630 | nanzhang
# Processing Record 401 of Set 630 | san quintin
# Processing Record 402 of Set 630 | torbay
# Processing Record 403 of Set 630 | maniitsoq
# Processing Record 404 of Set 630 | sao joao da barra
# Processing Record 405 of Set 630 | santiago
# Processing Record 406 of Set 630 | karoi
# City not found. Skipping...
# Processing Record 408 of Set 630 | pangnirtung
# Processing Record 409 of Set 630 | port blair
# Processing Record 410 of Set 630 | shelburne
# Processing Record 411 of Set 630 | port macquarie
# Processing Record 412 of Set 630 | sovetskaya
# Processing Record 413 of Set 630 | la primavera
# Processing Record 414 of Set 630 | saskylakh
# Processing Record 415 of Set 630 | kiruna
# Processing Record 416 of Set 630 | san policarpo
# City not found. Skipping...
# Processing Record 418 of Set 630 | port moresby
# Processing Record 419 of Set 630 | nkhata bay
# Processing Record 420 of Set 630 | kendari
# Processing Record 421 of Set 630 | banda aceh
# Processing Record 422 of Set 630 | modakeke
# City not found. Skipping...
# Processing Record 424 of Set 630 | morros
# Processing Record 425 of Set 630 | faya
# Processing Record 426 of Set 630 | albemarle
# Processing Record 427 of Set 630 | petropavlovsk-kamchatskiy
# Processing Record 428 of Set 630 | platnirovskaya
# Processing Record 429 of Set 630 | liverpool
# Processing Record 430 of Set 630 | beloha
# Processing Record 431 of Set 630 | upata
# Processing Record 432 of Set 630 | lumding
# Processing Record 433 of Set 630 | matagami
# Processing Record 434 of Set 630 | tianpeng
# Processing Record 435 of Set 630 | amahai
# Processing Record 436 of Set 630 | laguna de perlas
# Processing Record 437 of Set 630 | whakatane
# Processing Record 438 of Set 630 | saint-jean-de-braye
# Processing Record 439 of Set 630 | almeria
# Processing Record 440 of Set 630 | barcelos
# Processing Record 441 of Set 630 | kungurtug
# Processing Record 442 of Set 630 | russell
# Processing Record 443 of Set 630 | zhangye
# Processing Record 444 of Set 630 | vao
# Processing Record 445 of Set 630 | kisangani
# Processing Record 446 of Set 630 | ballina
# Processing Record 447 of Set 630 | sungaipenuh
# City not found. Skipping...
# Processing Record 449 of Set 630 | de-kastri
# Processing Record 450 of Set 630 | beihai
# Processing Record 451 of Set 630 | lavrentiya
# Processing Record 452 of Set 630 | cossato
# Processing Record 453 of Set 630 | broome
# Processing Record 454 of Set 630 | biak
# Processing Record 455 of Set 630 | fernandina beach
# Processing Record 456 of Set 630 | rorvik
# Processing Record 457 of Set 630 | kanniyakumari
# Processing Record 458 of Set 630 | siguiri
# Processing Record 459 of Set 630 | emmett
# Processing Record 460 of Set 630 | atambua
# Processing Record 461 of Set 630 | moroni
# Processing Record 462 of Set 630 | hollins
# Processing Record 463 of Set 630 | det udom
# Processing Record 464 of Set 630 | kharp
# City not found. Skipping...
# Processing Record 466 of Set 630 | vardo
# Processing Record 467 of Set 630 | broken hill
# City not found. Skipping...
# Processing Record 469 of Set 630 | neryungri
# Processing Record 470 of Set 630 | voi
# Processing Record 471 of Set 630 | mananjary
# Processing Record 472 of Set 630 | dagda
# Processing Record 473 of Set 630 | pitimbu
# Processing Record 474 of Set 630 | bambous virieux
# Processing Record 475 of Set 630 | boende
# City not found. Skipping...
# Processing Record 477 of Set 630 | rayagada
# Processing Record 478 of Set 630 | geraldton
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 481 of Set 630 | bulungu
# Processing Record 482 of Set 630 | makokou
# City not found. Skipping...
# Processing Record 484 of Set 630 | tamiahua
# Processing Record 485 of Set 630 | aginskoye
# Processing Record 486 of Set 630 | vrangel
# Processing Record 487 of Set 630 | zyryanka
# Processing Record 488 of Set 630 | denia
# Processing Record 489 of Set 630 | imbituba
# City not found. Skipping...
# Processing Record 491 of Set 630 | uyuni
# Processing Record 492 of Set 630 | naze
# Processing Record 493 of Set 630 | haines junction
# Processing Record 494 of Set 630 | macapa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 497 of Set 630 | ariquemes
# City not found. Skipping...
# Processing Record 499 of Set 630 | aswan
# Processing Record 500 of Set 630 | along
# Processing Record 501 of Set 630 | fort wellington
# Processing Record 502 of Set 630 | de aar
# Processing Record 503 of Set 630 | cidreira
# Processing Record 504 of Set 630 | san patricio
# Processing Record 505 of Set 630 | ibb
# Processing Record 506 of Set 630 | sinnamary
# Processing Record 507 of Set 630 | kundiawa
# Processing Record 508 of Set 630 | skibbereen
# Processing Record 509 of Set 630 | hailey
# Processing Record 510 of Set 630 | coahuayana
# City not found. Skipping...
# Processing Record 512 of Set 630 | linares
# Processing Record 513 of Set 630 | waitati
# Processing Record 514 of Set 630 | laguna
# Processing Record 515 of Set 630 | aurangabad
# Processing Record 516 of Set 630 | mandurah
# Processing Record 517 of Set 630 | monchegorsk
# Processing Record 518 of Set 630 | katsuura
# Processing Record 519 of Set 630 | marawi
# Processing Record 520 of Set 630 | mehran
# Processing Record 521 of Set 630 | hovd
# City not found. Skipping...
# Processing Record 523 of Set 630 | kayankulam
# Processing Record 524 of Set 630 | moron
# Processing Record 525 of Set 630 | jabinyanah
# Processing Record 526 of Set 630 | san vicente
# Processing Record 527 of Set 630 | lompoc
# Processing Record 528 of Set 630 | roma
# Processing Record 529 of Set 630 | bereda
# Processing Record 530 of Set 630 | hualmay
# Processing Record 531 of Set 630 | kangaatsiaq
# Processing Record 532 of Set 630 | pervomayskiy
# Processing Record 533 of Set 630 | svetlogorsk
# Processing Record 534 of Set 630 | el cocuy
# Processing Record 535 of Set 630 | saulkrasti
# Processing Record 536 of Set 630 | asbestos
# Processing Record 537 of Set 630 | omsukchan
# Processing Record 538 of Set 630 | lipin bor
# Processing Record 539 of Set 630 | xai-xai
# Processing Record 540 of Set 630 | sao gabriel
# Processing Record 541 of Set 630 | kontagora
# Processing Record 542 of Set 630 | tolaga bay
# Processing Record 543 of Set 630 | primorsk
# City not found. Skipping...
# Processing Record 545 of Set 630 | humaita
# Processing Record 546 of Set 630 | chazuta
# Processing Record 547 of Set 630 | lewistown
# Processing Record 548 of Set 630 | bukachacha
# Processing Record 549 of Set 630 | skelleftea
# Processing Record 550 of Set 630 | kudahuvadhoo
# Processing Record 551 of Set 630 | chieri
# Processing Record 552 of Set 630 | shelopugino
# Processing Record 553 of Set 630 | pisco
# Processing Record 554 of Set 630 | dingle
# Processing Record 555 of Set 630 | okha
# Processing Record 556 of Set 630 | senador jose porfirio
# Processing Record 557 of Set 630 | poplar bluff
# Processing Record 558 of Set 630 | kant
# Processing Record 559 of Set 630 | ujfeherto
# Processing Record 560 of Set 630 | galesong
# Processing Record 561 of Set 630 | puqi
# Processing Record 562 of Set 630 | temple
# Processing Record 563 of Set 630 | hermiston
# Processing Record 564 of Set 630 | kamariotissa
# Processing Record 565 of Set 630 | hiroshima
# Processing Record 566 of Set 630 | shenjiamen
# Processing Record 567 of Set 630 | akdepe
# Processing Record 568 of Set 630 | lazaro cardenas
# Processing Record 569 of Set 630 | mporokoso
# Processing Record 570 of Set 630 | artsyz
# Processing Record 571 of Set 630 | kalevala
# Processing Record 572 of Set 630 | vestmanna
# Processing Record 573 of Set 630 | kysyl-syr
# Processing Record 574 of Set 630 | pocone
# City not found. Skipping...
# Processing Record 576 of Set 630 | todos santos
# City not found. Skipping...
# Processing Record 578 of Set 630 | gwadar
# Processing Record 579 of Set 630 | coquimbo
# Processing Record 580 of Set 630 | tongliao
# Processing Record 581 of Set 630 | jalingo
# Processing Record 582 of Set 630 | cairns
# Processing Record 583 of Set 630 | mapastepec
# Processing Record 584 of Set 630 | san juan
# Processing Record 585 of Set 630 | lasa
# Processing Record 586 of Set 630 | zhezkazgan
# Processing Record 587 of Set 630 | ilinge
# Processing Record 588 of Set 630 | grindavik
# City not found. Skipping...
# Processing Record 590 of Set 630 | newport news
# Processing Record 591 of Set 630 | fairbanks
# Processing Record 592 of Set 630 | pacific grove
# Processing Record 593 of Set 630 | oranjemund
# City not found. Skipping...
# Processing Record 595 of Set 630 | balurghat
# Processing Record 596 of Set 630 | kassala
# Processing Record 597 of Set 630 | sorland
# Processing Record 598 of Set 630 | rosetown
# Processing Record 599 of Set 630 | berdigestyakh
# Processing Record 600 of Set 630 | hobyo
# Processing Record 601 of Set 630 | iganga
# Processing Record 602 of Set 630 | sulangan
# Processing Record 603 of Set 630 | enid
# City not found. Skipping...
# Processing Record 605 of Set 630 | padang
# Processing Record 606 of Set 630 | college
# City not found. Skipping...
# Processing Record 608 of Set 630 | nanakuli
# Processing Record 609 of Set 630 | hadsund
# Processing Record 610 of Set 630 | coruripe
# Processing Record 611 of Set 630 | loncoche
# Processing Record 612 of Set 630 | filadelfia
# Processing Record 613 of Set 630 | guatire
# Processing Record 614 of Set 630 | kaili
# Processing Record 615 of Set 630 | puerto del rosario
# Processing Record 616 of Set 630 | nouadhibou
# Processing Record 617 of Set 630 | kunming
# Processing Record 618 of Set 630 | atherton
# Processing Record 619 of Set 630 | zhanaozen
# Processing Record 620 of Set 630 | tornio
# Processing Record 621 of Set 630 | mount isa
# Processing Record 622 of Set 630 | riyadh
# Processing Record 623 of Set 630 | hamilton
# Processing Record 624 of Set 630 | belmonte
# Processing Record 625 of Set 630 | grand-santi
# Processing Record 626 of Set 630 | eureka
# Processing Record 627 of Set 630 | casablanca
# City not found. Skipping...
# Processing Record 629 of Set 630 | zhigansk
# City not found. Skipping...
# -------------------------------------------------------------------------
# Data Retrieval Complete
# -------------------------------------------------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
lat = []
lon =[]
temp = []
validcity =[]
windspeed =[]
cloudiness =[]
humidity =[]
country =[]
dt =[]
for cityitem in weather_data_list:
    validcity.append(cityitem['name'])
    lat.append(cityitem['coord']['lat'])
    lon.append(cityitem['coord']['lon'])
    #temp.append(cityitem['main']['temp_max'])
    fahrenheit_temp = round((cityitem['main']['temp_max'] * 1.8) + 32 ,2)
    temp.append(fahrenheit_temp)
    #windspeed.append(cityitem['wind']['speed'])
    windspeed_mph = round((cityitem['wind']['speed'] * 2.237),2)
    windspeed.append(windspeed_mph)
    cloudiness.append(cityitem['clouds']['all'])
    humidity.append(cityitem['main']['humidity'])
    dt.append(cityitem['dt'])
    country.append(cityitem['sys']['country'])

# %%
print(len(validcity))
print(len(cloudiness))
print(len(country))
print(len(dt))
print(len(humidity))
print(len(lat))
print(len(lon))
print(len(temp))
print(len(windspeed))
# Out:
# 569
# 569
# 569
# 569
# 569
# 569
# 569
# 569
# 569

# %%
weather_dict = {
    "City": validcity,
    "Cloudiness": cloudiness,
    "Country":country,
    "Date":dt,
    "Humidity":humidity,
    "Lat": lat,
    "Lng": lon,
    "Max Temp": temp,
    "Wind Speed":windspeed
}
weather_data = pd.DataFrame(weather_dict)

# Export file as a CSV, without the Pandas index, but with the header
weather_data.to_csv(output_data_file, index=False, header=True)
weather_data.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0   Rio Cuarto          40      AR  1548363600        70 -33.13  -64.35
# 1    Caracuaro           0      MX  1548365842        31  19.01 -101.13
# 2     Kudymkar          80      RU  1548365844        80  59.01   54.66
# 3  Polovinnoye           0      RU  1548365845        60  54.79   65.99
# 4    Coihaique          40      CL  1548363600        59 -45.58  -72.07
#
#    Max Temp  Wind Speed
# 0     84.20       28.86
# 1     77.07        4.16
# 2      1.33       11.65
# 3    -12.44        4.61
# 4     64.40       13.87

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature(01/23/19)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/TemperaturevsLatitude.png")

# Show plot
plt.show()

# %% [markdown]
# #Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity(01/23/19)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/HumidityvsLatitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness(01/23/19)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/CloudinessvsLatitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed(01/23/19)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/windspeedvsLatitude.png")

# Show plot
plt.show()
